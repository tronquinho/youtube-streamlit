# %%
import pandas as pd
import matplotlib.pyplot as plt
import yfinance as yf

# %matplotlib inline

# %%
def get_data(days, tickers):
    df = pd.DataFrame()
    for company in tickers.keys():
    # company = 'facebook'
        tkr = yf.Ticker(tickers[company])
        hist = tkr.history(period=f'{days}d')
        hist.index = hist.index.strftime('%d %B %Y')
        hist = hist[['Close']]
        hist.columns = [company]
        hist = hist.T
        hist.index.name = 'Name'
        df = pd.concat([df, hist])
    return df

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

get_data(days, tickers)
# Out:
#            11 February 2022  14 February 2022  15 February 2022  \
# Name
# apple            168.639999        168.880005        172.789993
# facebook         219.550003        217.699997        221.000000
# google          2685.649902       2710.520020       2732.169922
# microsoft        294.431213        294.391296        299.850006
# netflix          391.309998        396.570007        407.459991
# amazon          3065.870117       3103.340088       3130.209961
#
#            16 February 2022  17 February 2022  18 February 2022  \
# Name
# apple            172.550003        168.880005        167.300003
# facebook         216.539993        207.710007        206.160004
# google          2754.760010       2650.780029       2608.060059
# microsoft        299.500000        290.730011        287.929993
# netflix          398.079987        386.670013        391.290009
# amazon          3162.010010       3093.050049       3052.030029
#
#            22 February 2022  23 February 2022  24 February 2022  \
# Name
# apple            164.320007        160.070007        162.740005
# facebook         202.080002        198.449997        207.600006
# google          2596.270020       2551.760010       2653.820068
# microsoft        287.720001        280.269989        294.589996
# netflix          377.380005        367.459991        390.029999
# amazon          3003.949951       2896.540039       3027.159912
#
#            25 February 2022  28 February 2022  01 March 2022  02 March 2022  \
# Name
# apple            164.850006        165.119995     163.199997     166.559998
# facebook         210.479996        211.029999     203.490005     208.110001
# google          2689.189941       2701.139893    2681.229980    2691.429932
# microsoft        297.309998        298.790009     294.950012     300.190002
# netflix          390.799988        394.519989     386.239990     380.029999
# amazon          3075.770020       3071.260010    3022.840088    3041.050049
#
#            03 March 2022  04 March 2022  07 March 2022  08 March 2022  \
# Name
# apple         166.229996     163.169998     159.300003     157.440002
# facebook      202.970001     200.059998     187.470001     190.289993
# google       2677.989990    2638.129883    2527.570068    2542.090088
# microsoft     295.920013     289.859985     278.910004     275.850006
# netflix       368.070007     361.730011     350.260010     341.760010
# amazon       2957.969971    2912.820068    2749.060059    2720.290039
#
#            09 March 2022  10 March 2022  11 March 2022
# Name
# apple         162.949997     158.520004     154.729996
# facebook      198.500000     195.210007     187.610001
# google       2668.399902    2648.590088    2597.409912
# microsoft     288.500000     285.589996     280.070007
# netflix       358.790009     356.769989     340.320007
# amazon       2785.580078    2936.350098    2910.489990

# %%
aapl = yf.Ticker('AAPL')

# %%
aapl.info
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-4862e8b68a4f> in <module>
# ----> 1 aapl.info
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/yfinance/ticker.py in info(self)
#     145     @property
#     146     def info(self):
# --> 147         return self.get_info()
#     148
#     149     @property
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     635
#     636     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 637         self._get_fundamentals(proxy=proxy)
#     638         data = self._info
#     639         if as_dict:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/yfinance/base.py in _get_fundamentals(self, kind, proxy)
#     480
#     481         # get fundamentals
# --> 482         data = utils.get_json(ticker_url + '/financials', proxy, self.session)
#     483
#     484         # generic patterns
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/yfinance/utils.py in get_json(url, proxy, session)
#      97 def get_json(url, proxy=None, session=None):
#      98     session = session or _requests
# ---> 99     html = session.get(url=url, proxies=proxy, headers=user_agent_headers).text
#     100
#     101     if "QuoteSummaryStore" not in html:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      73     """
#      74
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     527         }
#     528         send_kwargs.update(settings)
# --> 529         resp = self.send(prep, **send_kwargs)
#     530
#     531         return resp
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     643
#     644         # Send the request
# --> 645         r = adapter.send(request, **kwargs)
#     646
#     647         # Total elapsed time of the request (approximately)
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438         try:
#     439             if not chunked:
# --> 440                 resp = conn.urlopen(
#     441                     method=request.method,
#     442                     url=url,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     701
#     702             # Make the request on the httplib connection object.
# --> 703             httplib_response = self._make_request(
#     704                 conn,
#     705                 method,
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384         # Trigger any extra validation we need to do.
#     385         try:
# --> 386             self._validate_conn(conn)
#     387         except (SocketTimeout, BaseSSLError) as e:
#     388             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1038         # Force connect early to allow us to validate the connection.
#    1039         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1040             conn.connect()
#    1041
#    1042         if not conn.is_verified:
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     356     def connect(self):
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#     360         tls_in_tls = False
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:

# %%
aapl.actions.head()
# Out:
#             Dividends  Stock Splits
# Date
# 1987-05-11   0.000536           0.0
# 1987-06-16   0.000000           2.0
# 1987-08-10   0.000536           0.0
# 1987-11-17   0.000714           0.0
# 1988-02-12   0.000714           0.0

# %%
# !pip3 install altair
# Out:
# Requirement already satisfied: altair in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (4.2.0)
# Requirement already satisfied: jsonschema>=3.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from altair) (3.2.0)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from altair) (1.18.1)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from altair) (2.10.3)
# Requirement already satisfied: pandas>=0.18 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from altair) (0.25.3)
# Requirement already satisfied: entrypoints in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from altair) (0.3)
# Requirement already satisfied: toolz in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from altair) (0.11.2)
# Requirement already satisfied: six>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jsonschema>=3.0->altair) (1.14.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jsonschema>=3.0->altair) (41.2.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jsonschema>=3.0->altair) (0.15.7)
# Requirement already satisfied: attrs>=17.4.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jsonschema>=3.0->altair) (19.3.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->altair) (1.1.1)
# Requirement already satisfied: pytz>=2017.2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=0.18->altair) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from pandas>=0.18->altair) (2.8.1)
# WARNING: You are using pip version 20.0.2; however, version 22.0.4 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import altair as alt

# %%
days = 20
tickers = {
    'apple': 'AAPL',
    'facebook': 'FB',
    'google': 'GOOGL',
    'microsoft': 'MSFT',
    'netflix': 'NFLX',
    'amazon': 'AMZN'
}

df = pd.DataFrame()
for company in tickers.keys():
# company = 'facebook'
    tkr = yf.Ticker(tickers[company])
    hist = tkr.history(period=f'{days}d')
    hist.index = hist.index.strftime('%d %B %Y')
    hist = hist[['Close']]
    hist.columns = [company]
    hist = hist.T
    hist.index.name = 'Name'
    df = pd.concat([df, hist])

# %%
df
# Out:
#            11 February 2022  14 February 2022  15 February 2022  \
# Name
# apple            168.639999        168.880005        172.789993
# facebook         219.550003        217.699997        221.000000
# google          2685.649902       2710.520020       2732.169922
# microsoft        294.431213        294.391296        299.850006
# netflix          391.309998        396.570007        407.459991
# amazon          3065.870117       3103.340088       3130.209961
#
#            16 February 2022  17 February 2022  18 February 2022  \
# Name
# apple            172.550003        168.880005        167.300003
# facebook         216.539993        207.710007        206.160004
# google          2754.760010       2650.780029       2608.060059
# microsoft        299.500000        290.730011        287.929993
# netflix          398.079987        386.670013        391.290009
# amazon          3162.010010       3093.050049       3052.030029
#
#            22 February 2022  23 February 2022  24 February 2022  \
# Name
# apple            164.320007        160.070007        162.740005
# facebook         202.080002        198.449997        207.600006
# google          2596.270020       2551.760010       2653.820068
# microsoft        287.720001        280.269989        294.589996
# netflix          377.380005        367.459991        390.029999
# amazon          3003.949951       2896.540039       3027.159912
#
#            25 February 2022  28 February 2022  01 March 2022  02 March 2022  \
# Name
# apple            164.850006        165.119995     163.199997     166.559998
# facebook         210.479996        211.029999     203.490005     208.110001
# google          2689.189941       2701.139893    2681.229980    2691.429932
# microsoft        297.309998        298.790009     294.950012     300.190002
# netflix          390.799988        394.519989     386.239990     380.029999
# amazon          3075.770020       3071.260010    3022.840088    3041.050049
#
#            03 March 2022  04 March 2022  07 March 2022  08 March 2022  \
# Name
# apple         166.229996     163.169998     159.300003     157.440002
# facebook      202.970001     200.059998     187.470001     190.289993
# google       2677.989990    2638.129883    2527.570068    2542.090088
# microsoft     295.920013     289.859985     278.910004     275.850006
# netflix       368.070007     361.730011     350.260010     341.760010
# amazon       2957.969971    2912.820068    2749.060059    2720.290039
#
#            09 March 2022  10 March 2022  11 March 2022
# Name
# apple         162.949997     158.520004     154.729996
# facebook      198.500000     195.210007     187.610001
# google       2668.399902    2648.590088    2597.409912
# microsoft     288.500000     285.589996     280.070007
# netflix       358.790009     356.769989     340.320007
# amazon       2785.580078    2936.350098    2910.489990

# %%
companies = ['apple', 'facebook']
data = df.loc[companies]
data
# Out:
#           11 February 2022  14 February 2022  15 February 2022  \
# Name
# apple           168.639999        168.880005        172.789993
# facebook        219.550003        217.699997        221.000000
#
#           16 February 2022  17 February 2022  18 February 2022  \
# Name
# apple           172.550003        168.880005        167.300003
# facebook        216.539993        207.710007        206.160004
#
#           22 February 2022  23 February 2022  24 February 2022  \
# Name
# apple           164.320007        160.070007        162.740005
# facebook        202.080002        198.449997        207.600006
